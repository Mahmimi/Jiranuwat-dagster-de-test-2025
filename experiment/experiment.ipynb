# %%
import pandas as pd

# %%
df = pd.read_excel("D:/Jiranuwat/Onboarding/Jiranuwat-dagster-de-test-2025/dagster_pipelines/data/BG020 สัญญาปกติ + consign 62 63 64 65 66 67 V2.XLSX")

# %%
df.head()
# Out:
#    Purchasing Document  Item    Material  \
# 0           1400015633     5  10034208.0
# 1           1400015686     1  30042793.0
# 2           1400015686     2  39007896.0
# 3           1400015686     3  30014836.0
# 4           1400015686     4  30022286.0
#
#                                 Short Text  Net Price  Target Quantity  \
# 0              ผงหมึก Brother รุ่น TN-3478     2675.0           1500.0
# 1  Nitrogen gases purity 99.999%, 7.0 ลบ.ม     1273.3              3.0
# 2                     Acetylene Instrument     2782.0              8.0
# 3                  Argon Ultra High Purity     2996.0              4.0
# 4                     Helium Grade 99.999%     8239.0              5.0
#
#   Order Unit     PR Doc.  Total Target Val.  Total open value  ...  PO SKU  \
# 0        Z0B  1100786567         13375000.0               0.0  ...     NaN
# 1        TUB  1100806597            80752.9           40874.0  ...     NaN
# ...

# %%
df.columns.__len__()
# Out:
# 98
